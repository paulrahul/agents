# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.12)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.12)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.

# %%
# First let's do an import. If you get an Import Error, see Q5 and then Q25 here: https://edwarddonner.com/avatar

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file might have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to Q5 and Q25 in the FAQ at https://edwarddonner.com/avatar
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "Tell me a fun fact"}]

# %%
messages

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 5.4 nano, an incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 5.4 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
question = response.choices[0].message.content
print(question)

# %%
# form a new messages list

messages = [{"role": "user", "content": question}]
messages

# %%
# Ask the model to answer the hard question

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
answer = response.choices[0].message.content
print(answer)

# %%
from IPython.display import Markdown, display

display(Markdown(answer))

# %%
message = f"""
Here is a question:
{question}

And here is a possible answer that might be correct or incorrect:
{answer}

Please evaluate if the answer is correct or incorrect.
"""

print(message)

# %%
messages = [{"role": "user", "content": message}]
response = openai.chat.completions.create(model="gpt-5.4", messages=messages)
print(response.choices[0].message.content)

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity

# First create the messages:
question = "Pick a business area that might be worth exploring for an Agentic AI opportunity. Respond only with the business area name and one line description."
messages = [{"role": "user", "content": question}]

# Then make the call:
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
business_area = response.choices[0].message.content
print(f"""
Question: {question}

Answer: {business_area}
""")

# Then read the business idea:
question = f"""
Given this business area:
{business_area}

Present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.
"""
messages = [{"role": "user", "content": question}]
response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
pain_point = response.choices[0].message.content
print(f"""
Question: {question}

Answer: {pain_point}
""")

# third LLM call propose the Agentic AI solution.
question = f"""
Given this business area:
{business_area}

And paint point:
{pain_point}

Propose an Agentic AI solution.
"""
messages = [{"role": "user", "content": question}]
response = openai.chat.completions.create(model="gpt-5.4", messages=messages)
pain_point = response.choices[0].message.content
print(f"""
Question: {question}

Answer: {pain_point}
""")
# Out:
# Question: Pick a business area that might be worth exploring for an Agentic AI opportunity. Respond only with the business area name and one line description.
#
# Answer: Personalized Healthcare Patient Triage and Care Navigation — Agentic AI that routes patients to the right level of care, summarizes histories, and coordinates follow-ups across providers.
#
#
# Question:
# Given this business area:
# Personalized Healthcare Patient Triage and Care Navigation — Agentic AI that routes patients to the right level of care, summarizes histories, and coordinates follow-ups across providers.
#
# Present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.
#
#
# Answer: A major pain point in personalized healthcare triage and care navigation is **patients getting stuck in the wrong care path because their history is fragmented across systems and their symptoms are interpreted inconsistently**.
#
# Why it’s hard:
# - Patients often contact different entry points: primary care, urgent care, ER, telehealth, specialists, insurer nurse lines.
# - Each provider sees only part of the picture: meds, prior diagnoses, recent tests, referrals, and follow-up gaps are scattered across EHRs, portals, and patient memory.
# - Symptom descriptions are often incomplete or non-standard, making it difficult to determine urgency and appropriate next steps.
# - This leads to:
#   - delayed care for high-risk patients,
#   - unnecessary ER visits or specialist referrals,
#   - duplicated tests and imaging,
#   - missed follow-ups after discharge,
#   - poor coordination between providers.
#
# Why it’s ripe for an Agentic AI solution:
# An agentic system could continuously gather and reconcile patient context from multiple sources, summarize relevant history in plain language, triage based on risk and guideline logic, and actively coordinate next steps—such as scheduling, referral routing, reminders, and follow-up tracking—rather than just giving a static recommendation.
#
# If you want, I can also turn this into:
# 1. a sharper startup problem statement,
# 2. a one-sentence pitch, or
# 3. a list of 5 adjacent pain points in the same space.
#
#
# Question:
# Given this business area:
# Personalized Healthcare Patient Triage and Care Navigation — Agentic AI that routes patients to the right level of care, summarizes histories, and coordinates follow-ups across providers.
#
# And paint point:
# A major pain point in personalized healthcare triage and care navigation is **patients getting stuck in the wrong care path because their history is fragmented across systems and their symptoms are interpreted inconsistently**.
#
# Why it’s hard:
# - Patients often contact different entry points: primary care, urgent care, ER, telehealth, specialists, insurer nurse lines.
# - Each provider sees only part of the picture: meds, prior diagnoses, recent tests, referrals, and follow-up gaps are scattered across EHRs, portals, and patient memory.
# - Symptom descriptions are often incomplete or non-standard, making it difficult to determine urgency and appropriate next steps.
# - This leads to:
#   - delayed care for high-risk patients,
#   - unnecessary ER visits or specialist referrals,
#   - duplicated tests and imaging,
#   - missed follow-ups after discharge,
#   - poor coordination between providers.
#
# Why it’s ripe for an Agentic AI solution:
# An agentic system could continuously gather and reconcile patient context from multiple sources, summarize relevant history in plain language, triage based on risk and guideline logic, and actively coordinate next steps—such as scheduling, referral routing, reminders, and follow-up tracking—rather than just giving a static recommendation.
#
# If you want, I can also turn this into:
# 1. a sharper startup problem statement,
# 2. a one-sentence pitch, or
# 3. a list of 5 adjacent pain points in the same space.
#
# Propose an Agentic AI solution.
#
#
# Answer: ## Agentic AI Solution: Longitudinal Patient Triage & Care Navigation Copilot
#
# ### 1. What it is
# An **agentic care navigation platform** that acts like an always-on clinical operations layer between patients, providers, and care settings.
#
# It does four things continuously:
# 1. **Collects and reconciles patient context** from fragmented sources.
# 2. **Assesses triage urgency and appropriate care setting** using guideline-based and risk-aware logic.
# 3. **Generates clear summaries** for patients and clinicians.
# 4. **Executes follow-through**: scheduling, referrals, reminders, escalation, and closed-loop follow-up.
#
# This is not just a chatbot. It is a **workflow agent system** that can take action across care pathways while keeping humans in the loop for clinical oversight.
#
# ---
#
# ## 2. Core product concept
#
# ### Product name
# **CarePath AI**
# An agentic patient triage and navigation orchestration layer.
#
# ### Primary users
# - Health systems
# - Payers / insurer care management teams
# - Value-based care organizations / ACOs
# - Telehealth platforms
# - Large multispecialty groups
# - Post-discharge care coordination teams
#
# ### End users
# - Patients seeking care
# - Nurses / triage staff
# - PCP offices
# - Specialists
# - Care navigators / case managers
# - Discharge coordinators
#
# ---
#
# ## 3. The problem it solves
# Today, a patient may describe the same issue to:
# - a portal bot,
# - a nurse hotline,
# - urgent care,
# - PCP,
# - specialist office,
# - and later the ER.
#
# Each interaction starts from partial context. That causes:
# - inconsistent triage,
# - poor urgency assessment,
# - repeat intake,
# - duplicate tests,
# - poor referral matching,
# - no one owning follow-up.
#
# **CarePath AI** creates a **single dynamic patient context layer** and uses it to route patients to the right care level and ensure the next step actually happens.
#
# ---
#
# ## 4. How the agentic system works
#
# ## A. Key agents in the system
#
# ### 1. Intake Agent
# Collects information from:
# - patient conversation via SMS/app/web/voice
# - prior EHR records
# - claims data
# - lab/imaging feeds
# - meds list / pharmacy data
# - referral history
# - discharge summaries
# - wearable or remote monitoring data, if available
#
# It asks adaptive follow-up questions:
# - symptom onset
# - severity
# - duration
# - red flags
# - comorbidities
# - recent procedures
# - current meds
# - pregnancy / immunocompromised status / age risks
#
# **Goal:** produce a normalized symptom and context profile.
#
# ---
#
# ### 2. Record Reconciliation Agent
# Builds a **longitudinal patient snapshot** by reconciling fragmented data across systems:
# - duplicate diagnoses
# - conflicting medication lists
# - recent admissions
# - open referrals
# - missing follow-ups
# - abnormal results without closure
#
# It highlights uncertainty:
# - “Medication list inconsistent across 2 sources”
# - “Recent CT result found, but no documented follow-up”
# - “Cardiology referral placed 21 days ago, not scheduled”
#
# **Goal:** turn fragmented records into a usable care context.
#
# ---
#
# ### 3. Risk & Triage Agent
# Uses:
# - symptom severity logic
# - evidence-based protocols
# - condition-specific pathways
# - utilization/risk signals
# - social and access factors
#
# It recommends appropriate next steps such as:
# - self-care
# - nurse callback
# - same-day virtual visit
# - PCP within 24–72 hours
# - specialist referral
# - urgent care
# - emergency department
# - post-discharge escalation
#
# It also identifies high-risk patients:
# - chest pain with risk history
# - sepsis indicators
# - post-op complications
# - uncontrolled chronic disease
# - medication side effects
# - abnormal test follow-up gaps
#
# **Goal:** determine urgency and care setting safely and consistently.
#
# ---
#
# ### 4. Summary Agent
# Creates tailored summaries for different audiences.
#
# #### For clinicians:
# - concise HPI-style summary
# - timeline of relevant events
# - medications
# - recent tests and findings
# - unresolved issues
# - suggested triage rationale
#
# #### For patients:
# - plain-language explanation
# - why this care setting is recommended
# - what information to bring
# - warning signs that require escalation
#
# **Goal:** reduce repeat storytelling and improve handoff quality.
#
# ---
#
# ### 5. Navigation & Scheduling Agent
# Takes the recommended next step and executes it:
# - books PCP or specialist appointments
# - finds in-network providers
# - routes referrals
# - initiates prior auth workflow if needed
# - sends visit prep instructions
# - coordinates transportation or interpreter support if integrated
# - places patient on waitlists for earlier appointments
#
# **Goal:** remove operational friction after triage.
#
# ---
#
# ### 6. Follow-up Closure Agent
# Tracks whether the care plan actually happened:
# - Did patient attend?
# - Was the referral completed?
# - Were abnormal labs reviewed?
# - Was discharge follow-up scheduled?
# - Did symptoms worsen?
# - Was the prescription filled?
#
# If not, it triggers:
# - reminders
# - outreach
# - nurse review
# - escalation to care manager
# - alternate routing if barriers persist
#
# **Goal:** prevent patients from falling out of the care pathway.
#
# ---
#
# ### 7. Safety & Escalation Agent
# Monitors for:
# - red-flag symptoms
# - conflicting clinical information
# - high uncertainty
# - vulnerable populations
# - repeated care-seeking without resolution
#
# It automatically escalates to:
# - human triage nurse
# - on-call clinician
# - ED recommendation
# - emergency services prompt when appropriate
#
# **Goal:** ensure safe boundaries and human oversight.
#
# ---
#
# ## 5. Example end-to-end workflow
#
# ### Scenario: Shortness of breath after recent discharge
# 1. Patient messages: “I’m feeling more short of breath today.”
# 2. **Intake Agent** asks:
#    - when did it start?
#    - chest pain?
#    - fever?
#    - oxygen level?
#    - recent hospitalization?
# 3. **Record Reconciliation Agent** discovers:
#    - discharged 4 days ago after heart failure admission
#    - diuretic dose changed
#    - missed follow-up appointment
#    - recent BNP elevated
# 4. **Risk & Triage Agent** classifies patient as high risk.
# 5. **Summary Agent** prepares:
#    - “Recent CHF discharge, worsening dyspnea, missed follow-up, med change, potential fluid overload.”
# 6. **Safety Agent** recommends urgent same-day evaluation or ED depending on red flags.
# 7. **Navigation Agent**:
#    - contacts heart failure clinic,
#    - books urgent slot,
#    - sends transport options,
#    - shares summary with clinician.
# 8. **Follow-up Closure Agent** checks within hours:
#    - Did patient confirm attendance?
#    - If not, escalates to nurse outreach.
#
# This is a true **closed-loop navigation system**, not just advice.
#
# ---
#
# ## 6. Product features
#
# ### Patient-facing
# - Conversational symptom intake via app, SMS, web, voice
# - Plain-language care recommendations
# - Appointment/referral coordination
# - Follow-up reminders
# - Care plan tracking
# - Multilingual support
#
# ### Provider-facing
# - Longitudinal patient summary
# - Triage rationale and urgency score
# - Open-loop alerts: missed referrals, abnormal result gaps, discharge follow-up gaps
# - Intake note drafted into EHR workflow
# - Inbox and basket reduction via structured summaries
# - Human override and review queue
#
# ### Admin / care management
# - Population-level triage dashboard
# - Escalation queue
# - Referral leakage tracking
# - Post-discharge follow-up tracking
# - Access bottleneck analytics
# - Audit trail for all AI actions and decisions
#
# ---
#
# ## 7. Why agentic AI is the right approach
# A normal AI assistant can say:
# > “You may want to see a doctor.”
#
# An agentic system can:
# - gather missing context,
# - evaluate risk,
# - choose a care pathway,
# - book the visit,
# - notify the right team,
# - remind the patient,
# - detect if the appointment was missed,
# - and re-route if needed.
#
# That is exactly what this domain needs: **reasoning + orchestration + persistence + follow-through**.
#
# ---
#
# ## 8. Differentiation
# This solution stands apart from:
# - symptom checker apps,
# - generic healthcare chatbots,
# - static care management dashboards,
# - EHR-native but siloed triage tools.
#
# ### Differentiators
# 1. **Longitudinal context reconciliation**
#    - not just current symptom intake
# 2. **Cross-setting routing**
#    - PCP, urgent care, specialist, telehealth, ER, post-discharge
# 3. **Closed-loop execution**
#    - scheduling, referral completion, reminders, escalation
# 4. **Multi-stakeholder summaries**
#    - patient + clinician + navigator views
# 5. **Human-in-the-loop safety design**
#    - nurse or clinician oversight for high-risk scenarios
#
# ---
#
# ## 9. Technical architecture
#
# ### Data inputs
# - EHR integrations via FHIR / HL7
# - claims data
# - pharmacy data
# - lab/imaging feeds
# - referral management systems
# - scheduling systems
# - CRM / care management systems
# - patient-reported data
# - device data when applicable
#
# ### Intelligence layers
# - clinical NLP for history extraction
# - entity resolution for record matching
# - guideline/rule engine for triage logic
# - risk stratification models
# - LLM summarization and dialogue
# - workflow orchestration engine
# - uncertainty detection and escalation policies
#
# ### Action layer
# - scheduling APIs
# - referral order routing
# - messaging / call center integration
# - nurse queue / case management queue
# - reminders and outreach channels
# - audit logs and compliance controls
#
# ---
#
# ## 10. Safety model
# Because this touches clinical triage, safety is critical.
#
# ### Guardrails
# - guideline-constrained recommendations
# - confidence thresholds
# - mandatory human review for high-risk categories
# - transparent rationale for triage decisions
# - red-flag symptom hard stops
# - no autonomous diagnosis claims
# - full auditability
# - versioned clinical protocols
# - escalation on ambiguous or conflicting data
#
# ### Human-in-the-loop moments
# - possible emergency symptoms
# - pediatric / pregnancy / oncology / post-op edge cases
# - medication interaction concerns
# - repeated contacts with worsening symptoms
# - conflicting data across sources
#
# ---
#
# ## 11. Business model
#
# ### Buyers
# - health systems wanting lower avoidable ED utilization and better care coordination
# - payers wanting better navigation and lower leakage/costs
# - value-based care groups wanting quality + utilization improvement
#
# ### Pricing models
# - PMPM for covered populations
# - per discharge episode
# - per triage interaction
# - enterprise SaaS + implementation
# - shared savings tied to avoidable utilization reduction
#
# ---
#
# ## 12. ROI hypothesis
#
# ### Operational ROI
# - fewer manual triage calls
# - reduced intake time for clinicians
# - lower no-show / referral drop-off
# - fewer duplicated tests
# - lower inbox burden
#
# ### Clinical / utilization ROI
# - reduced avoidable ER visits
# - faster escalation for high-risk cases
# - improved post-discharge follow-up
# - reduced readmissions
# - better specialist routing accuracy
#
# ### Patient ROI
# - less repeat storytelling
# - faster access to appropriate care
# - clearer next steps
# - fewer missed handoffs
#
# ---
#
# ## 13. Ideal wedge / MVP
#
# ### Best first use case
# **Post-discharge care navigation + symptom triage for high-risk chronic patients**
#
# Why this wedge works:
# - strong ROI from preventing readmissions
# - high fragmentation pain
# - clear follow-up workflows
# - measurable outcomes
# - easier buyer urgency
#
# ### MVP scope
# - 1–2 health systems
# - integrate discharge summaries, meds, appointments
# - conversational symptom intake
# - rule-based red-flag triage
# - clinician summary generation
# - follow-up scheduling and reminder workflows
# - escalation dashboard for nurses
#
# ### MVP success metrics
# - % discharge follow-up completed within 7 days
# - readmission rate reduction
# - time to appropriate visit
# - referral completion rate
# - triage-to-scheduled-appointment conversion
# - patient satisfaction / resolution rate
#
# ---
#
# ## 14. Example one-sentence pitch
# **CarePath AI is an agentic healthcare navigation platform that reconciles fragmented patient history, triages symptoms safely, and coordinates the next best care step across providers until the loop is closed.**
#
# ---
#
# ## 15. Why this could become a strong company
# This sits at the intersection of:
# - healthcare access,
# - clinical operations,
# - utilization management,
# - patient engagement,
# - and care coordination.
#
# The pain is large, frequent, measurable, and expensive.
# The workflow is repetitive but high stakes.
# And the value is not just in prediction, but in **orchestrated action across messy healthcare systems**.
#
# If you want, I can next turn this into:
# 1. a **startup-style product spec**,
# 2. a **multi-agent system architecture diagram in words**, or
# 3. a **GTM plan with ideal customer profile and wedge market**.
